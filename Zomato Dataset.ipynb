# %%
#Importing important libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the dataset
df=pd.read_csv('zomato.csv')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
#Loading another dataset where Country Code column is similar with the previous dataset
Country=pd.read_excel('Country-Code.xlsx')

# %%
Country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
Country.shape
# Out:
# (15, 2)

# %%
df['Country Code']
# Out:
# 0       162
# 1       162
# 2       162
# 3       162
# 4       162
#        ...
# 9546    208
# 9547    208
# 9548    208
# 9549    208
# 9550    208
# Name: Country Code, Length: 9551, dtype: int64

# %%
#Merging both the datasets
Final_dataset=pd.merge(df,Country,how='left',on='Country Code')

# %%
Final_dataset
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
Final_dataset.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
Final_dataset.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
Final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
Final_dataset.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# #### The Cuisines column has the null values.

# %%
Final_dataset.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
Final_dataset.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
Final_dataset.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# South Africa        60
# Brazil              60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# ## Observation
# India has the more records or transaction history followed by United States and United Kingdom.

# %%
plt.pie(Final_dataset.Country.value_counts()[:3],labels=Final_dataset.Country.value_counts().index[:3],labeldistance=1.1,radius=2)
# Out:
# ([<matplotlib.patches.Wedge at 0x286e0aa1250>,
# ...
#  [Text(-2.1659485401904206, 0.3855734965567345, 'India'),
#   Text(2.154563431676712, -0.44481054268246595, 'United States'),
#   Text(2.199173030764607, -0.06031567588624146, 'United Kingdom')])

# %%
User_rating=Final_dataset.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Counting'})

# %%
User_rating
# Out:
#     Aggregate rating Rating color Rating text  Counting
# 0                0.0        White   Not rated      2148
# 1                1.8          Red        Poor         1
# 2                1.9          Red        Poor         2
# 3                2.0          Red        Poor         7
# 4                2.1          Red        Poor        15
# 5                2.2          Red        Poor        27
# 6                2.3          Red        Poor        47
# 7                2.4          Red        Poor        87
# 8                2.5       Orange     Average       110
# 9                2.6       Orange     Average       191
# 10               2.7       Orange     Average       250
# 11               2.8       Orange     Average       315
# 12               2.9       Orange     Average       381
# 13               3.0       Orange     Average       468
# 14               3.1       Orange     Average       519
# 15               3.2       Orange     Average       522
# ...

# %% [markdown]
# ## Observation
# After using Zomato, most of the customers are not even rated the service.

# %%
sns.distplot(User_rating['Aggregate rating'])
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: xlabel='Aggregate rating', ylabel='Density'>

# %%
plt.figure(figsize=[12,6])
sns.barplot(x='Aggregate rating',y='Counting',data=User_rating,hue='Rating text')
# Out:
# <AxesSubplot: xlabel='Aggregate rating', ylabel='Counting'>

# %% [markdown]
# ## Observation
# Majority of the customers give the average and good rating.

# %%
Final_dataset.groupby(['Aggregate rating','Country']).size().reset_index()
# Out:
#      Aggregate rating         Country     0
# 0                 0.0          Brazil     5
# 1                 0.0           India  2139
# 2                 0.0  United Kingdom     1
# 3                 0.0   United States     3
# 4                 1.8           India     1
# ..                ...             ...   ...
# 217               4.9       Sri Lanka     1
# 218               4.9          Turkey     3
# 219               4.9             UAE     4
# 220               4.9  United Kingdom     4
# 221               4.9   United States    14
#
# [222 rows x 3 columns]

# %% [markdown]
# ## Observation
# Majority of the Indians are not providing any rating to the services.

# %%
Highest_country_rating=Final_dataset[Final_dataset['Aggregate rating']>=4.5].groupby([Final_dataset['Country']]).size().reset_index().rename(columns={0:'Count'})
Highest_country_rating
# Out:
#            Country  Count
# 0        Australia      1
# 1           Brazil     16
# 2            India    116
# 3        Indonesia      7
# 4      New Zealand     12
# 5      Phillipines     12
# 6            Qatar      4
# 7     South Africa     12
# 8        Sri Lanka      2
# 9           Turkey     10
# 10             UAE     18
# 11  United Kingdom     23
# 12   United States     68

# %%
plt.figure(figsize=[18,7])
sns.barplot(x='Country',y='Count',data=Highest_country_rating)
# Out:
# <AxesSubplot: xlabel='Country', ylabel='Count'>

# %% [markdown]
# ## Observation
# Out of all the customers who rated excellent are from India.

# %%
Final_dataset.groupby(['Country','Has Online delivery']).size().reset_index()
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %%
Final_dataset[Final_dataset['Has Online delivery']=='Yes'].groupby([Final_dataset['Country']]).size().reset_index()
# Out:
#   Country     0
# 0   India  2423
# 1     UAE    28

# %% [markdown]
# ## Observation
# Only in Inda and UAE have the online delivery services.

# %%
Final_dataset[Final_dataset['Country']=='India'].City.value_counts()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Lucknow           21
# Bhubaneshwar      21
# Ahmedabad         21
# Guwahati          21
# Amritsar          21
# Indore            20
# Vizag             20
# Bangalore         20
# Surat             20
# Allahabad         20
# Varanasi          20
# Kanpur            20
# Goa               20
# Vadodara          20
# Coimbatore        20
# Chennai           20
# Aurangabad        20
# Patna             20
# Kolkata           20
# Mangalore         20
# Mumbai            20
# Jaipur            20
# Dehradun          20
# Ludhiana          20
# Nagpur            20
# Mysore            20
# Pune              20
# Kochi             20
# Bhopal            20
# Nashik            20
# Agra              20
# Puducherry        20
# Ranchi            20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Mohali             1
# Panchkula          1
# ...

# %%
plt.pie(x=Final_dataset[Final_dataset['Country']=='India'].City.value_counts().values[:4],labels=Final_dataset[Final_dataset['Country']=='India'].City.value_counts().index[:4])
# Out:
# ([<matplotlib.patches.Wedge at 0x286e4e63e50>,
# ...
#  [Text(-0.6207499702746028, 0.9081131396495042, 'New Delhi'),
#   Text(0.07888824382658387, -1.0971675555656746, 'Gurgaon'),
#   Text(0.8905335390443715, -0.6457166683903298, 'Noida'),
#   Text(1.0945551812130687, -0.10931127700117002, 'Faridabad')])

# %% [markdown]
# ## Observation
# In India, most of the records are from New Delhi which followed by Gurgaon, Noida and Faridabad.

# %%
Final_dataset['Cuisines'].value_counts()[:10]
# Out:
# North Indian                      936
# North Indian, Chinese             511
# Fast Food                         354
# Chinese                           354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64

# %% [markdown]
# ## Observation
# Top 10 famous cuisines.

# %%
Final_dataset[Final_dataset['Country']=='India'].Cuisines.value_counts()[:10]
# Out:
# North Indian                      936
# North Indian, Chinese             511
# Fast Food                         348
# Chinese                           340
# North Indian, Mughlai             334
# Cafe                              279
# Bakery                            216
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64

# %% [markdown]
# ## Observation
# Top 10 cuisines have ordred in India.
